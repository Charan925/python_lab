# %%
a=int(input("enter A value"))
b=int(input("enter B value"))
print("sum value is:",a+b)
# Out:
# enter A value45
# enter B value45
# sum value is: 90

# %%
a=int(input("enter any number"))
if a>0:
  print("number is positive:")
elif a<0:
    print("number is negative")
else:
      print("number is zero")
# Out:
# enter any number45
# number is positive:

# %%
a=int(input("enter the value of A:"))
b=int(input("enter the value of B:"))
c=int(input("enter the value of C:"))
if(a>b) and (a>c):
  print("A is largest")
elif(b>a)and (b>c):
  print("B is largest")
else:
  print("C is largest")
# Out:
# enter the value of A:10
# enter the value of B:20
# enter the value of C:30
# C is largest

# %%
d=int(input("enter number between 1 to 7:"))
if d==1:
    print("monday")
elif d==2:
    print("tuesday")
elif d==3:
    print("wednesday")    
elif d==4:
    print("thursday")
elif d==5:
    print("friday")    
elif d==6:
    print("saturday")
elif d==7:
    print("sunday")
else:
    print("enter valid option")
# Out:
# enter number between 1 to 7:3
# wednesday
