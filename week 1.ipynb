# %%
x=[1,2,3,4,5,6,"excellent"]
print(x)
print(type(x))
print(x[1:4])
# Out:
# [1, 2, 3, 4, 5, 6, 'excellent']
# <class 'list'>
# [2, 3, 4]

# %%
#insert
x=[1,2,3,4,5,"excellent"]
print(x)
x.insert(5,"Hello World")
print(x)
# Out:
# [1, 2, 3, 4, 5, 'excellent']
# [1, 2, 3, 4, 5, 'Hello World', 'excellent']

# %%
x=[1,2,3,4,5,"excellent"]
print(x)
x.remove(4)
print(x)
# Out:
# [1, 2, 3, 4, 5, 'excellent']
# [1, 2, 3, 5, 'excellent']

# %%
x=[1,2,3,4,5,"excellent"]
print(x)
x.append("python")
print(x)
# Out:
# [1, 2, 3, 4, 5, 'excellent']
# [1, 2, 3, 4, 5, 'excellent', 'python']

# %%
x=[1,2,3,4,5,"excellent"]
print(len(x))
# Out:
# 6

# %%
x=[1,2,3,4,5,"excellent"]
print(x)
x.pop(4)
print(x)
# Out:
# [1, 2, 3, 4, 5, 'excellent']
# [1, 2, 3, 4, 'excellent']

# %%
x=[1,2,3,4,5,"excellent"]
y=["yo","nice"]
x.extend(y)
print(x)
# Out:
# [1, 2, 3, 4, 5, 'excellent', 'yo', 'nice']

# %%
x=[1,2,3,4,5,"excellent"]
print(list(reversed(x)))
# Out:
# ['excellent', 5, 4, 3, 2, 1]

# %%
x=[1,2,3,4,5,"excellent"]
print(x)
x.clear()
print(x)
# Out:
# [1, 2, 3, 4, 5, 'excellent']
# []

# %%
d={1:'A',2:'B',3:'C',4:'D',5:'E'}
print(d)
print(type(d))
print(d.values())
print(d.pop(4))
# Out:
# {1: 'A', 2: 'B', 3: 'C', 4: 'D', 5: 'E'}
# <class 'dict'>
# dict_values(['A', 'B', 'C', 'D', 'E'])
# D

# %%
d={1:'A',2:'B',3:'C',4:'D',5:'E'}
print(len(d))
# Out:
# 5

# %%
d={1:'A',2:'B',3:'C',4:'D',5:'E'}
x=d[1]
print(x)
# Out:
# A

# %%
d={1:'A',2:'B',3:'C',4:'D',5:'E'}
print(d)
y=d.get(5)
print(y)
# Out:
# {1: 'A', 2: 'B', 3: 'C', 4: 'D', 5: 'E'}
# E

# %%
d={1:'A',2:'B',3:'C',4:'D',5:'E'}
print(d)
d[5]='k'
print(d)
# Out:
# {1: 'A', 2: 'B', 3: 'C', 4: 'D', 5: 'E'}
# {1: 'A', 2: 'B', 3: 'C', 4: 'D', 5: 'k'}

# %%
x=(1,2,3,4,5,6)
print(x)
print(type(x))
print(x[2])
print(x[0:3])
# Out:
# (1, 2, 3, 4, 5, 6)
# <class 'tuple'>
# 3
# (1, 2, 3)

# %%
x=(1,2,3,4,5,6)
print(x)
t=list(x)
t.append(7)
x=tuple(t)
print(x)
# Out:
# (1, 2, 3, 4, 5, 6)
# (1, 2, 3, 4, 5, 6, 7)

# %%
x=(1,2,3,4,5,6)
print(len(x))
# Out:
# 6

# %%
x=(1,2,3,4,5,6)
print(any(x))
if 7 in x:
    print("element found")
else:
    print("element not found")
for name in ('A','B'):
    print("hello",name)
# Out:
# True
# element not found
# hello A
# hello B

# %%
s={3,5,6,8}
print(s)
print(type(s))
s.add("hello")
print(s)
s.remove(3)
print(s)
print(len(s))
s.discard(9)
print(s)
s.pop()
print(s)
s.clear()
print(s)
# Out:
# {8, 3, 5, 6}
# <class 'set'>
# {3, 5, 6, 8, 'hello'}
# {5, 6, 8, 'hello'}
# 4
# {5, 6, 8, 'hello'}
# {6, 8, 'hello'}
# set()
